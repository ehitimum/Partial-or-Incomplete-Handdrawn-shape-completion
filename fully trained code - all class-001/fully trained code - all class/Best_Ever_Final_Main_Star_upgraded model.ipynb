# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer, Conv2DTranspose,Input,Reshape
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import optimizers
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

import os
import matplotlib.pyplot as plt
import numpy as np
from IPython import display

# %%
import cv2
import PIL
from keras import backend
#from random import randint
from google.colab import files
import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_start_index = 0
train_end_index = 600

test_start_index = 600
test_end_index = 900

# %%
dirname="/content/drive/MyDrive/colab/dataset/dataset/complete/";
files=['star/']
labels=[1]

# %%
import re 
import math
from pathlib import Path 

file_pattern = re.compile(r'.*?(\d+).*?')
def get_order(file):
    match = file_pattern.match(Path(file).name)
    if not match:
        return math.inf
    return int(match.groups()[0])

sorted_files = sorted(files, key=get_order)

# %%
import os
def sortKeyFunc(s):
    return int(os.path.basename(s)[:-4])

# %%
images=[]
y=[]

for i in range(len(files)):
    cfiles=glob.glob(dirname+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images.append(newimg)
        y.append(labels[i])

# %%
X=np.array(images)
y=np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (900, 56, 56)
# (900,)

# %%
dirname2="/content/drive/MyDrive/colab/dataset/dataset/partial/";
images2=[]
y2=[]
for i in range(len(files)):
    cfiles=glob.glob(dirname2+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images2.append(newimg)
        y2.append(labels[i])
X2=np.array(images2)
y2=np.array(y2)
print(X2.shape)
print(y2.shape)
# Out:
# (900, 56, 56)
# (900,)

# %%
fig = plt.figure
plt.imshow(X[1], cmap='gray')
plt.show()
plt.imshow(X2[1], cmap='gray')
plt.show()

# %%
# define leaky ReLU function
def lrelu(x, alpha=0.1):
    return tf.math.maximum(alpha*x, x)

# %%
training_set=[]
train_lev=[]
for i in range(train_start_index, train_end_index):
  training_set.append(X[i])
  train_lev.append(y[i])
  train_imgs=np.array(training_set)
  train_labels=np.array(train_lev)
print(train_imgs.shape)
print(train_labels.shape)  

testing_set=[]
test_lev=[]
for i in range(test_start_index,test_end_index):
  testing_set.append(X[i])
  test_lev.append(y[i])
  test_imgs=np.array(testing_set)
  test_labels=np.array(test_lev)
print(test_imgs.shape)   
print(test_labels.shape)
# Out:
# (600, 56, 56)
# (600,)
# (300, 56, 56)
# (300,)

# %%
train_imgs, test_imgs = train_imgs / 255.0, test_imgs / 255.0 
print(train_imgs.shape)
# Out:
# (600, 56, 56)

# %%
# check data array shapes:
print("Size of train images: {}, Number of train images: {}".format(train_imgs.shape[-2:], train_imgs.shape[0]))
print("Size of test images: {}, Number of test images: {}".format(test_imgs.shape[-2:], test_imgs.shape[0]))
# Out:
# Size of train images: (56, 56), Number of train images: 600
# Size of test images: (56, 56), Number of test images: 300

# %%
# plot distorted image example from training images
image_id_to_plot = 20
plt.imshow(tf.squeeze(train_imgs[image_id_to_plot]), cmap='gray')
plt.title("The number is: {}".format(train_labels[image_id_to_plot]))
plt.show()

# plot distorted image example from test images
plt.imshow(tf.squeeze(test_imgs[image_id_to_plot]), cmap='gray')
plt.title("The number is: {}".format(test_labels[image_id_to_plot]))
plt.show()
plt.close()

# %%
num_pixels = 56*56
train_imgs = train_imgs.reshape((train_end_index-train_start_index), num_pixels).astype('float32')
test_imgs = test_imgs.reshape((test_end_index-test_start_index), num_pixels).astype('float32')
print(train_imgs.shape)
# Out:
# (600, 3136)

# %%
# load mnist dataset
#(train_imgs, train_labels), (test_imgs, test_labels) = tf.keras.datasets.mnist.load_data()

# fit image pixel values from 0 to 1
#train_imgs, test_imgs = train_imgs / 255.0, test_imgs / 255.0

# %%
# prepare training reference images: add new dimension
#train_imgs_data = train_imgs[..., tf.newaxis]
# prepare test reference images: add new dimension
#test_imgs_data = test_imgs[..., tf.newaxis]

# %%
# add noise to the images for train and test cases
#def distort_image(input_imgs, noise_factor=0.5):
#    noisy_imgs = input_imgs + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=input_imgs.shape) 
#    noisy_imgs = np.clip(noisy_imgs, 0., 1.)
#    return noisy_imgs

# prepare distorted input data for training
#train_noisy_imgs = distort_image(train_imgs_data)

# prepare distorted input data for evaluation
#test_noisy_imgs = distort_image(test_imgs_data)

# %%
training_partial_set=[]
train_partial_lev=[]
for i in range(train_start_index,train_end_index):
  training_partial_set.append(X2[i])
  train_partial_lev.append(y2[i])
  train_partial_imgs=np.array(training_partial_set)
  train_partial_labels=np.array(train_partial_lev)
print(train_partial_imgs.shape)
print(train_partial_labels.shape)  

testing_partial_set=[]
test_partial_lev=[]
for i in range(test_start_index,test_end_index):
  testing_partial_set.append(X2[i])
  test_partial_lev.append(y2[i])
  test_partial_imgs=np.array(testing_partial_set)
  test_partial_labels=np.array(test_partial_lev)
print(test_partial_imgs.shape)   
print(test_partial_labels.shape)
# Out:
# (600, 56, 56)
# (600,)
# (300, 56, 56)
# (300,)

# %%
# plot distorted image example from training images
from tensorflow._api.v2.compat.v1 import train
image_id_to_plot = 20
plt.imshow(tf.squeeze(train_partial_imgs[image_id_to_plot]), cmap='gray')
plt.title("The number is: {}".format(train_partial_labels[image_id_to_plot]))
plt.show()

# plot distorted image example from test images
plt.imshow(tf.squeeze(test_partial_imgs[image_id_to_plot]), cmap='gray')
plt.title("The number is: {}".format(test_partial_labels[image_id_to_plot]))
plt.show()
plt.close()

# %%
num_pixels = 56*56
train_partial_imgs = train_partial_imgs.reshape((train_end_index-train_start_index), num_pixels).astype('float32')
test_partial_imgs = test_partial_imgs.reshape((test_end_index-test_start_index), num_pixels).astype('float32')
print(train_imgs.shape)
# Out:
# (600, 3136)

# %%
enco_deco = Sequential()
# Encoder
enco_deco.add(Dense(2500, input_dim=num_pixels, activation='LeakyReLU'))
enco_deco.add(Dense(2000, activation='LeakyReLU'))
enco_deco.add(Dense(1500, activation='LeakyReLU'))
enco_deco.add(Dense(1000, activation='LeakyReLU'))
enco_deco.add(Dense(500, activation='LeakyReLU'))
enco_deco.add(Dense(100, activation='LeakyReLU'))

#decoder
enco_deco.add(Dense(300, activation='LeakyReLU'))
enco_deco.add(Dense(500, activation='LeakyReLU'))
enco_deco.add(Dense(1000, activation='LeakyReLU'))
enco_deco.add(Dense(2000, activation='LeakyReLU'))
enco_deco.add(Dense(3136, activation='sigmoid'))
enco_deco.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2500)              7842500
#
#  dense_1 (Dense)             (None, 2000)              5002000
#
#  dense_2 (Dense)             (None, 1500)              3001500
#
#  dense_3 (Dense)             (None, 1000)              1501000
#
#  dense_4 (Dense)             (None, 500)               500500
#
#  dense_5 (Dense)             (None, 100)               50100
#
#  dense_6 (Dense)             (None, 300)               30300
#
#  dense_7 (Dense)             (None, 500)               150500
#
#  dense_8 (Dense)             (None, 1000)              501000
#
#  dense_9 (Dense)             (None, 2000)              2002000
#
#  dense_10 (Dense)            (None, 3136)              6275136
#
# =================================================================
# Total params: 26,856,536
# Trainable params: 26,856,536
# Non-trainable params: 0
# _________________________________________________________________

# %%
def cost_function(labels=None, logits=None, name=None):
    loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=logits, name=name)
    return tf.reduce_mean(loss)
learning_rate = 1e-5    
enco_deco.compile(optimizer=tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate),loss='binary_crossentropy',metrics=None)
#enco_deco.compile(loss='mean_squared_error', optimizer='adam')

# %%
histry=enco_deco.fit(train_partial_imgs, train_imgs, validation_data=(test_partial_imgs, test_imgs), epochs=1000,
                     workers=1,batch_size=300, shuffle=True)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 4s 1s/step - loss: 3.0068 - val_loss: 1.8525
# Epoch 2/1000
# 2/2 [==============================] - 2s 1s/step - loss: 1.6948 - val_loss: 1.3460
# Epoch 3/1000
# 2/2 [==============================] - 2s 1s/step - loss: 1.2765 - val_loss: 1.1437
# Epoch 4/1000
# 2/2 [==============================] - 2s 1s/step - loss: 1.0982 - val_loss: 1.0215
# Epoch 5/1000
# 2/2 [==============================] - 2s 1s/step - loss: 1.0023 - val_loss: 0.9480
# Epoch 6/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.9397 - val_loss: 0.9068
# Epoch 7/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.9011 - val_loss: 0.8827
# Epoch 8/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.8771 - val_loss: 0.8600
# Epoch 9/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.8528 - val_loss: 0.8356
# Epoch 10/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.8274 - val_loss: 0.8162
# Epoch 11/1000
# 2/2 [==============================] - 3s 2s/step - loss: 0.8082 - val_loss: 0.8021
# Epoch 12/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7938 - val_loss: 0.7891
# Epoch 13/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7800 - val_loss: 0.7761
# Epoch 14/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7662 - val_loss: 0.7643
# Epoch 15/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7542 - val_loss: 0.7543
# Epoch 16/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7442 - val_loss: 0.7454
# Epoch 17/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7349 - val_loss: 0.7369
# Epoch 18/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7262 - val_loss: 0.7291
# Epoch 19/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7183 - val_loss: 0.7217
# Epoch 20/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7108 - val_loss: 0.7149
# Epoch 21/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.7041 - val_loss: 0.7089
# Epoch 22/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6978 - val_loss: 0.7036
# Epoch 23/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6920 - val_loss: 0.6986
# Epoch 24/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6864 - val_loss: 0.6937
# Epoch 25/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6810 - val_loss: 0.6889
# Epoch 26/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6757 - val_loss: 0.6843
# Epoch 27/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6708 - val_loss: 0.6798
# Epoch 28/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6659 - val_loss: 0.6755
# Epoch 29/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6611 - val_loss: 0.6713
# Epoch 30/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6562 - val_loss: 0.6671
# Epoch 31/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6513 - val_loss: 0.6627
# Epoch 32/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6464 - val_loss: 0.6582
# Epoch 33/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6414 - val_loss: 0.6535
# Epoch 34/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6363 - val_loss: 0.6488
# Epoch 35/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6312 - val_loss: 0.6440
# Epoch 36/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6260 - val_loss: 0.6393
# Epoch 37/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6207 - val_loss: 0.6344
# Epoch 38/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6153 - val_loss: 0.6295
# Epoch 39/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6098 - val_loss: 0.6244
# Epoch 40/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6041 - val_loss: 0.6192
# Epoch 41/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5984 - val_loss: 0.6141
# Epoch 42/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5926 - val_loss: 0.6089
# Epoch 43/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5868 - val_loss: 0.6037
# Epoch 44/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5809 - val_loss: 0.5985
# Epoch 45/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5750 - val_loss: 0.5932
# Epoch 46/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5690 - val_loss: 0.5880
# Epoch 47/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5631 - val_loss: 0.5828
# Epoch 48/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5571 - val_loss: 0.5776
# Epoch 49/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5512 - val_loss: 0.5725
# Epoch 50/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5454 - val_loss: 0.5676
# Epoch 51/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5397 - val_loss: 0.5628
# Epoch 52/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5340 - val_loss: 0.5581
# Epoch 53/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5285 - val_loss: 0.5534
# Epoch 54/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5231 - val_loss: 0.5490
# Epoch 55/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5179 - val_loss: 0.5448
# Epoch 56/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5129 - val_loss: 0.5408
# Epoch 57/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5081 - val_loss: 0.5369
# Epoch 58/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5035 - val_loss: 0.5333
# Epoch 59/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4991 - val_loss: 0.5300
# Epoch 60/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4949 - val_loss: 0.5269
# Epoch 61/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4909 - val_loss: 0.5240
# Epoch 62/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4872 - val_loss: 0.5212
# Epoch 63/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4836 - val_loss: 0.5187
# Epoch 64/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4803 - val_loss: 0.5164
# Epoch 65/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4773 - val_loss: 0.5143
# Epoch 66/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4744 - val_loss: 0.5124
# Epoch 67/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4718 - val_loss: 0.5107
# Epoch 68/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4693 - val_loss: 0.5092
# Epoch 69/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4670 - val_loss: 0.5078
# Epoch 70/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4649 - val_loss: 0.5065
# Epoch 71/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4630 - val_loss: 0.5053
# Epoch 72/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4612 - val_loss: 0.5043
# Epoch 73/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4596 - val_loss: 0.5033
# Epoch 74/1000
# 2/2 [==============================] - 4s 2s/step - loss: 0.4581 - val_loss: 0.5025
# Epoch 75/1000
# 2/2 [==============================] - 4s 2s/step - loss: 0.4567 - val_loss: 0.5017
# Epoch 76/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4554 - val_loss: 0.5010
# Epoch 77/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4543 - val_loss: 0.5004
# Epoch 78/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4532 - val_loss: 0.4998
# Epoch 79/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4522 - val_loss: 0.4992
# Epoch 80/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4513 - val_loss: 0.4988
# Epoch 81/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4505 - val_loss: 0.4983
# Epoch 82/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4497 - val_loss: 0.4978
# Epoch 83/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4490 - val_loss: 0.4973
# Epoch 84/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4484 - val_loss: 0.4970
# Epoch 85/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4477 - val_loss: 0.4966
# Epoch 86/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4472 - val_loss: 0.4963
# Epoch 87/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4466 - val_loss: 0.4959
# Epoch 88/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4461 - val_loss: 0.4956
# Epoch 89/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4457 - val_loss: 0.4953
# Epoch 90/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4452 - val_loss: 0.4950
# Epoch 91/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4448 - val_loss: 0.4947
# Epoch 92/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4444 - val_loss: 0.4945
# Epoch 93/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4440 - val_loss: 0.4942
# Epoch 94/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4437 - val_loss: 0.4939
# Epoch 95/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4433 - val_loss: 0.4937
# Epoch 96/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4430 - val_loss: 0.4934
# Epoch 97/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4427 - val_loss: 0.4932
# Epoch 98/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4424 - val_loss: 0.4930
# Epoch 99/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4421 - val_loss: 0.4929
# Epoch 100/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4418 - val_loss: 0.4927
# Epoch 101/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4416 - val_loss: 0.4924
# Epoch 102/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4413 - val_loss: 0.4922
# Epoch 103/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4411 - val_loss: 0.4921
# Epoch 104/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4408 - val_loss: 0.4919
# Epoch 105/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4406 - val_loss: 0.4918
# Epoch 106/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4404 - val_loss: 0.4916
# Epoch 107/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4401 - val_loss: 0.4913
# Epoch 108/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4399 - val_loss: 0.4911
# Epoch 109/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4397 - val_loss: 0.4909
# Epoch 110/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4395 - val_loss: 0.4908
# Epoch 111/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4393 - val_loss: 0.4907
# Epoch 112/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4391 - val_loss: 0.4906
# Epoch 113/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4389 - val_loss: 0.4904
# Epoch 114/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4387 - val_loss: 0.4902
# Epoch 115/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4385 - val_loss: 0.4901
# Epoch 116/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4383 - val_loss: 0.4899
# Epoch 117/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4382 - val_loss: 0.4898
# Epoch 118/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4380 - val_loss: 0.4897
# Epoch 119/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4378 - val_loss: 0.4895
# Epoch 120/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4376 - val_loss: 0.4893
# Epoch 121/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4374 - val_loss: 0.4892
# Epoch 122/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4373 - val_loss: 0.4890
# Epoch 123/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4371 - val_loss: 0.4889
# Epoch 124/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4369 - val_loss: 0.4888
# Epoch 125/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4368 - val_loss: 0.4886
# Epoch 126/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4366 - val_loss: 0.4885
# Epoch 127/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4364 - val_loss: 0.4883
# Epoch 128/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4362 - val_loss: 0.4881
# Epoch 129/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4361 - val_loss: 0.4881
# Epoch 130/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.
1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4217 - val_loss: 0.4778
# Epoch 195/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4214 - val_loss: 0.4776
# Epoch 196/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4211 - val_loss: 0.4774
# Epoch 197/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4208 - val_loss: 0.4772
# Epoch 198/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4205 - val_loss: 0.4770
# Epoch 199/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4202 - val_loss: 0.4767
# Epoch 200/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4199 - val_loss: 0.4764
# Epoch 201/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4196 - val_loss: 0.4763
# Epoch 202/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4193 - val_loss: 0.4761
# Epoch 203/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4190 - val_loss: 0.4759
# Epoch 204/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4186 - val_loss: 0.4756
# Epoch 205/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4183 - val_loss: 0.4754
# Epoch 206/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4180 - val_loss: 0.4752
# Epoch 207/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4177 - val_loss: 0.4751
# Epoch 208/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4174 - val_loss: 0.4747
# Epoch 209/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4170 - val_loss: 0.4744
# Epoch 210/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4167 - val_loss: 0.4743
# Epoch 211/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4164 - val_loss: 0.4740
# Epoch 212/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4161 - val_loss: 0.4738
# Epoch 213/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4158 - val_loss: 0.4735
# Epoch 214/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4154 - val_loss: 0.4732
# Epoch 215/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4151 - val_loss: 0.4730
# Epoch 216/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4148 - val_loss: 0.4729
# Epoch 217/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4145 - val_loss: 0.4726
# Epoch 218/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4142 - val_loss: 0.4724
# Epoch 219/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4138 - val_loss: 0.4721
# Epoch 220/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4135 - val_loss: 0.4719
# Epoch 221/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4132 - val_loss: 0.4716
# Epoch 222/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4129 - val_loss: 0.4715
# Epoch 223/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4126 - val_loss: 0.4713
# Epoch 224/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4123 - val_loss: 0.4708
# Epoch 225/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4119 - val_loss: 0.4709
# Epoch 226/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4116 - val_loss: 0.4707
# Epoch 227/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4113 - val_loss: 0.4701
# Epoch 228/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4110 - val_loss: 0.4699
# Epoch 229/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4107 - val_loss: 0.4701
# Epoch 230/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4104 - val_loss: 0.4696
# Epoch 231/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4101 - val_loss: 0.4692
# Epoch 232/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4097 - val_loss: 0.4692
# Epoch 233/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4094 - val_loss: 0.4690
# Epoch 234/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4091 - val_loss: 0.4685
# Epoch 235/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4088 - val_loss: 0.4682
# Epoch 236/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4085 - val_loss: 0.4683
# Epoch 237/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4082 - val_loss: 0.4679
# Epoch 238/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4079 - val_loss: 0.4674
# Epoch 239/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4076 - val_loss: 0.4675
# Epoch 240/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4073 - val_loss: 0.4673
# Epoch 241/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4070 - val_loss: 0.4669
# Epoch 242/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4067 - val_loss: 0.4666
# Epoch 243/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4064 - val_loss: 0.4665
# Epoch 244/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4061 - val_loss: 0.4664
# Epoch 245/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4058 - val_loss: 0.4659
# Epoch 246/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4055 - val_loss: 0.4658
# Epoch 247/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4052 - val_loss: 0.4655
# Epoch 248/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4049 - val_loss: 0.4652
# Epoch 249/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4046 - val_loss: 0.4651
# Epoch 250/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4043 - val_loss: 0.4648
# Epoch 251/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4040 - val_loss: 0.4645
# Epoch 252/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4037 - val_loss: 0.4644
# Epoch 253/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4034 - val_loss: 0.4641
# Epoch 254/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4032 - val_loss: 0.4637
# Epoch 255/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4029 - val_loss: 0.4634
# Epoch 256/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.4026 - val_loss: 0.4633
# Epoch 257/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.
1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3585 - val_loss: 0.4337
# Epoch 449/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3583 - val_loss: 0.4343
# Epoch 450/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3581 - val_loss: 0.4340
# Epoch 451/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3579 - val_loss: 0.4338
# Epoch 452/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3577 - val_loss: 0.4341
# Epoch 453/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3574 - val_loss: 0.4340
# Epoch 454/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3572 - val_loss: 0.4336
# Epoch 455/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3570 - val_loss: 0.4337
# Epoch 456/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3568 - val_loss: 0.4343
# Epoch 457/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3566 - val_loss: 0.4334
# Epoch 458/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3564 - val_loss: 0.4339
# Epoch 459/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3562 - val_loss: 0.4337
# Epoch 460/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3559 - val_loss: 0.4337
# Epoch 461/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3557 - val_loss: 0.4337
# Epoch 462/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3555 - val_loss: 0.4341
# Epoch 463/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3553 - val_loss: 0.4335
# Epoch 464/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3551 - val_loss: 0.4343
# Epoch 465/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3549 - val_loss: 0.4335
# Epoch 466/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3547 - val_loss: 0.4339
# Epoch 467/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3545 - val_loss: 0.4339
# Epoch 468/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3543 - val_loss: 0.4337
# Epoch 469/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3541 - val_loss: 0.4335
# Epoch 470/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3538 - val_loss: 0.4338
# Epoch 471/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3536 - val_loss: 0.4340
# Epoch 472/1000
# 2/2 [==============================] - 3s 2s/step - loss: 0.3533 - val_loss: 0.4332
# Epoch 473/1000
# 2/2 [==============================] - 4s 2s/step - loss: 0.3531 - val_loss: 0.4343
# Epoch 474/1000
# 2/2 [==============================] - 3s 2s/step - loss: 0.3530 - val_loss: 0.4334
# Epoch 475/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3527 - val_loss: 0.4339
# Epoch 476/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3525 - val_loss: 0.4337
# Epoch 477/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3523 - val_loss: 0.4338
# Epoch 478/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3521 - val_loss: 0.4331
# Epoch 479/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3519 - val_loss: 0.4339
# Epoch 480/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3516 - val_loss: 0.4338
# Epoch 481/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3514 - val_loss: 0.4338
# Epoch 482/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3512 - val_loss: 0.4332
# Epoch 483/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3510 - val_loss: 0.4339
# Epoch 484/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3507 - val_loss: 0.4336
# Epoch 485/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3505 - val_loss: 0.4337
# Epoch 486/1000
# ...
# Epoch 840/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2820 - val_loss: 0.4591
# Epoch 841/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2819 - val_loss: 0.4602
# Epoch 842/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2819 - val_loss: 0.4600
# Epoch 843/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2817 - val_loss: 0.4594
# Epoch 844/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2816 - val_loss: 0.4609
# Epoch 845/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2818 - val_loss: 0.4608
# Epoch 846/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2817 - val_loss: 0.4592
# Epoch 847/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2810 - val_loss: 0.4582
# Epoch 848/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2812 - val_loss: 0.4589
# Epoch 849/1000
# 2/2 [==============================] - 4s 2s/step - loss: 0.2809 - val_loss: 0.4619
# Epoch 850/1000
# 2/2 [==============================] - 3s 2s/step - loss: 0.2807 - val_loss: 0.4609
# Epoch 851/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - val_loss: 0.4599
# Epoch 852/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2801 - val_loss: 0.4589
# Epoch 853/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2801 - val_loss: 0.4602
# Epoch 854/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2798 - val_loss: 0.4614
# Epoch 855/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2797 - val_loss: 0.4616
# Epoch 856/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2795 - val_loss: 0.4609
# Epoch 857/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2792 - val_loss: 0.4604
# Epoch 858/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2791 - val_loss: 0.4601
# Epoch 859/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2789 - val_loss: 0.4601
# Epoch 860/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2788 - val_loss: 0.4616
# Epoch 861/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2786 - val_loss: 0.4620
# Epoch 862/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2785 - val_loss: 0.4625
# Epoch 863/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2784 - val_loss: 0.4624
# Epoch 864/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2784 - val_loss: 0.4624
# Epoch 865/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2785 - val_loss: 0.4621
# Epoch 866/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2784 - val_loss: 0.4629
# Epoch 867/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2781 - val_loss: 0.4638
# Epoch 868/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2778 - val_loss: 0.4640
# Epoch 869/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2776 - val_loss: 0.4631
# Epoch 870/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2771 - val_loss: 0.4615
# Epoch 871/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2770 - val_loss: 0.4620
# Epoch 872/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2769 - val_loss: 0.4619
# Epoch 873/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2769 - val_loss: 0.4623
# Epoch 874/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2769 - val_loss: 0.4618
# Epoch 875/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2770 - val_loss: 0.4615
# Epoch 876/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2772 - val_loss: 0.4622
# Epoch 877/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2768 - val_loss: 0.4631
# Epoch 878/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2762 - val_loss: 0.4636
# Epoch 879/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2758 - val_loss: 0.4630
# Epoch 880/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2757 - val_loss: 0.4631
# Epoch 881/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2757 - val_loss: 0.4634
# Epoch 882/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2755 - val_loss: 0.4632
# Epoch 883/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2751 - val_loss: 0.4640
# Epoch 884/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2750 - val_loss: 0.4643
# Epoch 885/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2750 - val_loss: 0.4642
# Epoch 886/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2748 - val_loss: 0.4638
# Epoch 887/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2746 - val_loss: 0.4635
# Epoch 888/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2747 - val_loss: 0.4637
# Epoch 889/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2748 - val_loss: 0.4634
# Epoch 890/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2746 - val_loss: 0.4641
# Epoch 891/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2740 - val_loss: 0.4654
# Epoch 892/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2738 - val_loss: 0.4654
# Epoch 893/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2736 - val_loss: 0.4646
# Epoch 894/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2735 - val_loss: 0.4653
# Epoch 895/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2736 - val_loss: 0.4654
# Epoch 896/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2734 - val_loss: 0.4671
# Epoch 897/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2734 - val_loss: 0.4675
# Epoch 898/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2734 - val_loss: 0.4664
# Epoch 899/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2731 - val_loss: 0.4654
# Epoch 900/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2726 - val_loss: 0.4647
# Epoch 901/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2724 - val_loss: 0.4647
# Epoch 902/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2727 - val_loss: 0.4656
# Epoch 903/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2727 - val_loss: 0.4663
# Epoch 904/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2726 - val_loss: 0.4673
# Epoch 905/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2724 - val_loss: 0.4664
# Epoch 906/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2718 - val_loss: 0.4655
# Epoch 907/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2714 - val_loss: 0.4659
# Epoch 908/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2716 - val_loss: 0.4666
# Epoch 909/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2715 - val_loss: 0.4689
# Epoch 910/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2712 - val_loss: 0.4684
# Epoch 911/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2710 - val_loss: 0.4686
# Epoch 912/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2708 - val_loss: 0.4670
# Epoch 913/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2707 - val_loss: 0.4658
# Epoch 914/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2708 - val_loss: 0.4650
# Epoch 915/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2708 - val_loss: 0.4663
# Epoch 916/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2704 - val_loss: 0.4677
# Epoch 917/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2703 - val_loss: 0.4675
# Epoch 918/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2703 - val_loss: 0.4675
# Epoch 919/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2700 - val_loss: 0.4669
# Epoch 920/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2698 - val_loss: 0.4664
# Epoch 921/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2697 - val_loss: 0.4668
# Epoch 922/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2693 - val_loss: 0.4678
# Epoch 923/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2690 - val_loss: 0.4686
# Epoch 924/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2689 - val_loss: 0.4689
# Epoch 925/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2687 - val_loss: 0.4694
# Epoch 926/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2686 - val_loss: 0.4685
# Epoch 927/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2685 - val_loss: 0.4689
# Epoch 928/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2683 - val_loss: 0.4686
# Epoch 929/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2682 - val_loss: 0.4681
# Epoch 930/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2682 - val_loss: 0.4682
# Epoch 931/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2684 - val_loss: 0.4682
# Epoch 932/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2684 - val_loss: 0.4690
# Epoch 933/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2684 - val_loss: 0.4698
# Epoch 934/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2678 - val_loss: 0.4703
# Epoch 935/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2672 - val_loss: 0.4698
# Epoch 936/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2672 - val_loss: 0.4705
# Epoch 937/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2674 - val_loss: 0.4710
# Epoch 938/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2671 - val_loss: 0.4705
# Epoch 939/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2668 - val_loss: 0.4712
# Epoch 940/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2667 - val_loss: 0.4706
# Epoch 941/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2667 - val_loss: 0.4700
# Epoch 942/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2663 - val_loss: 0.4695
# Epoch 943/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2661 - val_loss: 0.4699
# Epoch 944/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2663 - val_loss: 0.4709
# Epoch 945/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2661 - val_loss: 0.4723
# Epoch 946/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2658 - val_loss: 0.4729
# Epoch 947/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2655 - val_loss: 0.4722
# Epoch 948/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2652 - val_loss: 0.4718
# Epoch 949/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2651 - val_loss: 0.4708
# Epoch 950/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2649 - val_loss: 0.4705
# Epoch 951/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2649 - val_loss: 0.4703
# Epoch 952/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2649 - val_loss: 0.4702
# Epoch 953/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2647 - val_loss: 0.4717
# Epoch 954/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2644 - val_loss: 0.4728
# Epoch 955/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2643 - val_loss: 0.4739
# Epoch 956/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2643 - val_loss: 0.4737
# Epoch 957/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2640 - val_loss: 0.4740
# Epoch 958/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2638 - val_loss: 0.4735
# Epoch 959/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2639 - val_loss: 0.4725
# Epoch 960/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2642 - val_loss: 0.4729
# Epoch 961/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2645 - val_loss: 0.4733
# Epoch 962/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2641 - val_loss: 0.4730
# Epoch 963/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2635 - val_loss: 0.4737
# Epoch 964/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2633 - val_loss: 0.4726
# Epoch 965/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2635 - val_loss: 0.4705
# Epoch 966/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2637 - val_loss: 0.4709
# Epoch 967/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2630 - val_loss: 0.4731
# Epoch 968/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2630 - val_loss: 0.4753
# Epoch 969/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2633 - val_loss: 0.4753
# Epoch 970/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2624 - val_loss: 0.4717
# Epoch 971/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2623 - val_loss: 0.4710
# Epoch 972/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2623 - val_loss: 0.4728
# Epoch 973/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2616 - val_loss: 0.4756
# Epoch 974/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2617 - val_loss: 0.4762
# Epoch 975/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2614 - val_loss: 0.4743
# Epoch 976/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2611 - val_loss: 0.4734
# Epoch 977/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2612 - val_loss: 0.4737
# Epoch 978/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2608 - val_loss: 0.4755
# Epoch 979/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2609 - val_loss: 0.4770
# Epoch 980/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2609 - val_loss: 0.4760
# Epoch 981/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2605 - val_loss: 0.4750
# Epoch 982/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2604 - val_loss: 0.4751
# Epoch 983/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2603 - val_loss: 0.4765
# Epoch 984/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2601 - val_loss: 0.4782
# Epoch 985/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2601 - val_loss: 0.4775
# Epoch 986/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2598 - val_loss: 0.4763
# Epoch 987/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2597 - val_loss: 0.4755
# Epoch 988/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2597 - val_loss: 0.4760
# Epoch 989/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2593 - val_loss: 0.4770
# Epoch 990/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2592 - val_loss: 0.4785
# Epoch 991/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2594 - val_loss: 0.4791
# Epoch 992/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2594 - val_loss: 0.4785
# Epoch 993/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2594 - val_loss: 0.4790
# Epoch 994/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2598 - val_loss: 0.4802
# Epoch 995/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2604 - val_loss: 0.4813
# Epoch 996/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2600 - val_loss: 0.4790
# Epoch 997/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2584 - val_loss: 0.4774
# Epoch 998/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2583 - val_loss: 0.4756
# Epoch 999/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2586 - val_loss: 0.4751
# Epoch 1000/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2579 - val_loss: 0.4772

# %%
predictions = enco_deco.predict(test_partial_imgs)
print("prediction set", predictions.shape)
# Out:
# 10/10 [==============================] - 1s 59ms/step
# prediction set (300, 3136)

# %%
X_test = np.reshape(test_imgs, ((test_end_index-test_start_index),56,56)) *255
plt.figure(figsize=(20, 4))
print("Train images")
for i in range(5,10,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i,:,:], cmap='gray')
plt.show()
 
x_test_noisy = np.reshape(test_partial_imgs, (-1,56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(5,10,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_noisy[i,:,:], cmap='gray')
    plt.title("Partial Images")
plt.show()    
 
prediction = np.reshape(predictions, ((test_end_index-test_start_index),56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(5,10,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(prediction[i,:,:], cmap='gray')
    plt.title("Generated Images")  
plt.show()
# Out:
# Train images

# %%
# funstion for train and val losses visualizations
def plot_losses(results):
    plt.plot(results.history['loss'], 'bo', label='Training loss')
    plt.plot(results.history['val_loss'], 'r', label='Validation loss')
    plt.title('Training and validation loss',fontsize=14)
    plt.xlabel('Epochs ',fontsize=14)
    plt.ylabel('Loss',fontsize=14)
    plt.legend()
    plt.show()
    plt.close()

# visualize train and val losses
plot_losses(histry)

# %%
dirname3="/content/drive/MyDrive/colab/dataset/test1/partial/";
images3=[]
y3=[]
files=['star/']

for i in range(len(files)):
    cfiles=glob.glob(dirname3+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images3.append(newimg)
        y3.append(labels[i])
X3=np.array(images3)
y3=np.array(y3)
print(X3.shape)
print(y3.shape)
#########################################################################################################
dirname4="/content/drive/MyDrive/colab/dataset/test1/complete/";
images4=[]
y4=[]
files=['star/']

for i in range(len(files)):
    cfiles=glob.glob(dirname4+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images4.append(newimg)
        y4.append(labels[i])
X4=np.array(images4)
y4=np.array(y4)
print(X4.shape)
print(y4.shape)        
#############################################
testing_set_main=[]
test_lev_m=[]
for i in range(0,5):
  testing_set_main.append(X4[i])
  test_lev_m.append(y4[i])
  test_imgs=np.array(testing_set_main)
  test_labels=np.array(test_lev_m)
print(test_imgs.shape)   
print(test_labels.shape)

testing_partial=[]
test_partial_le=[]
for i in range(0,5):
  testing_partial.append(X3[i])
  test_partial_le.append(y3[i])
  test_partial_imgs=np.array(testing_partial)
  test_partial_labels=np.array(test_partial_le)
print(test_partial_imgs.shape)   
print(test_partial_labels.shape)
#########################################################
num_pixels = 56*56
test_partial_imgs = test_partial_imgs.reshape((5-0), num_pixels).astype('float32')
test_imgs = test_imgs.reshape((5-0), num_pixels).astype('float32')
print(test_partial_imgs.shape)
print(test_imgs.shape)
#############################################################
predictions = enco_deco.predict(test_partial_imgs)

print("prediction set", predictions.shape)
#############################################################
X_test = np.reshape(test_imgs, ((5-0),56,56)) *255
plt.figure(figsize=(20, 4))
print("Train images")
for i in range(0,5,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(X_test[i,:,:], cmap='gray')
plt.show() 
x_test_noisy = np.reshape(test_partial_imgs, (-1,56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(0,5,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_noisy[i,:,:], cmap='gray')
    plt.title("Partial Images")
plt.show()    
 
prediction = np.reshape(predictions, ((5-0),56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(0,5,1):
    plt.subplot(2, 10, i+1)
    plt.imshow(prediction[i,:,:], cmap='gray')
    plt.title("Generated Images")  
plt.show()
# Out:
# (5, 56, 56)
# (5,)
# (5, 56, 56)
# (5,)
# (5, 56, 56)
# (5,)
# (5, 56, 56)
# (5,)
# (5, 3136)
# (5, 3136)
# 1/1 [==============================] - 0s 49ms/step
# prediction set (5, 3136)
# Train images

# %%
image_id_to_plot = 0 #upto 0 to 4
partial_out = tf.squeeze(x_test_noisy[image_id_to_plot])
plt.imshow(partial_out, cmap='gray')
plt.title("Partial Images") 
plt.show()

output = tf.squeeze(prediction[image_id_to_plot])
plt.imshow(output, cmap='gray')
plt.title("Generated Images") 
plt.show()

# %%
image_id_to_plot = 1 #upto 0 to 4
partial_out = tf.squeeze(x_test_noisy[image_id_to_plot])
plt.imshow(partial_out, cmap='gray')
plt.title("Partial Images") 
plt.show()

output = tf.squeeze(prediction[image_id_to_plot])
plt.imshow(output, cmap='gray')
plt.title("Generated Images") 
plt.show()

# %%
image_id_to_plot = 2 #upto 0 to 4
partial_out = tf.squeeze(x_test_noisy[image_id_to_plot])
plt.imshow(partial_out, cmap='gray')
plt.title("Partial Images") 
plt.show()

output = tf.squeeze(prediction[image_id_to_plot])
plt.imshow(output, cmap='gray')
plt.title("Generated Images") 
plt.show()

# %%
image_id_to_plot = 3 #upto 0 to 4
partial_out = tf.squeeze(x_test_noisy[image_id_to_plot])
plt.imshow(partial_out, cmap='gray')
plt.title("Partial Images") 
plt.show()

output = tf.squeeze(prediction[image_id_to_plot])
plt.imshow(output, cmap='gray')
plt.title("Generated Images") 
plt.show()

# %%
image_id_to_plot = 4 #upto 0 to 4
partial_out = tf.squeeze(x_test_noisy[image_id_to_plot])
plt.imshow(partial_out, cmap='gray')
plt.title("Partial Images") 
plt.show()

output = tf.squeeze(prediction[image_id_to_plot])
plt.imshow(output, cmap='gray')
plt.title("Generated Images") 
plt.show()

# %%
dirname3="/content/drive/MyDrive/colab/dataset/test2/partial/";
images3=[]
y3=[]
files=['star/']

for i in range(len(files)):
    cfiles=glob.glob(dirname3+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images3.append(newimg)
        y3.append(labels[i])
X3=np.array(images3)
y3=np.array(y3)
print(X3.shape)
print(y3.shape)
#########################################################################################################
dirname4="/content/drive/MyDrive/colab/dataset/test2/complete/";
images4=[]
y4=[]

for i in range(len(files)):
    cfiles=glob.glob(dirname4+files[i]+'*.jpg')
    cfiles.sort(key=sortKeyFunc)
    
    for cf in cfiles:
        img=cv2.imread(cf)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        (thresh, imw) = cv2.threshold(img, 1, 1, 1)
        contours, _ = cv2.findContours(imw, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            rect = cv2.boundingRect(c)
            # if rect[2] < 100 or rect[3] < 100: 
            #   continue
            x11,y11,w11,h11 = rect
            # cv2.rectangle(img,(x11,y11),(x11+w11,y11+h11),(0,255,0),2)
        a11=x11
        b11=y11
        c11=x11+w11
        d11=y11+h11
        cropped_image = img[b11:d11 , a11:c11]
        newimg=cv2.resize(cropped_image, (56, 56))
        images4.append(newimg)
        y4.append(labels[i])
X4=np.array(images4)
y4=np.array(y4)
print(X4.shape)
print(y4.shape)        
#############################################
testing_set_main=[]
test_lev_m=[]
for i in range(0,6):
  testing_set_main.append(X4[i])
  test_lev_m.append(y4[i])
  test_imgs=np.array(testing_set_main)
  test_labels=np.array(test_lev_m)
print(test_imgs.shape)   
print(test_labels.shape)

testing_partial=[]
test_partial_le=[]
for i in range(0,6):
  testing_partial.append(X3[i])
  test_partial_le.append(y3[i])
  test_partial_imgs=np.array(testing_partial)
  test_partial_labels=np.array(test_partial_le)
print(test_partial_imgs.shape)   
print(test_partial_labels.shape)
################################################
test_partial_imgs = test_partial_imgs.reshape((6-0), num_pixels).astype('float32')
test_imgs = test_imgs.reshape((6-0), num_pixels).astype('float32')
print(test_partial_imgs.shape)
print(test_imgs.shape)
#############################################################
predictions = enco_deco.predict(test_partial_imgs)

print("prediction set", predictions.shape)
#############################################################
X_test = np.reshape(test_imgs, ((6-0),56,56)) *255
plt.figure(figsize=(20, 4))
print("Train images")
for i in range(0,5,1):
    plt.subplot(3, 10, i+1)
    plt.imshow(X_test[i,:,:], cmap='gray')
plt.show() 
x_test_noisy = np.reshape(test_partial_imgs, (-1,56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(0,5,1):
    plt.subplot(3, 10, i+1)
    plt.imshow(x_test_noisy[i,:,:], cmap='gray')
    plt.title("Partial Images")
plt.show()    
 
prediction = np.reshape(predictions, ((6-0),56,56)) *255
plt.figure(figsize=(20, 4))
for i in range(0,5,1):
    plt.subplot(3, 10, i+1)
    plt.imshow(prediction[i,:,:], cmap='gray')
    plt.title("Generated Images")  
plt.show()
# Out:
# (7, 56, 56)
# (7,)
# (7, 56, 56)
# (7,)
# (6, 56, 56)
# (6,)
# (6, 56, 56)
# (6,)
# (6, 3136)
# (6, 3136)
# 1/1 [==============================] - 0s 61ms/step
# prediction set (6, 3136)
# Train images
